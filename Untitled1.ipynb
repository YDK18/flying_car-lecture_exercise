# %%
import numpy as np
from sklearn.neighbors import KDTree
rng = np.random.RandomState(0)
X = rng.random_sample((10, 3))  # 10 points in 3 dimensions
tree = KDTree(X, leaf_size=2)              # doctest: +SKIP
#dist, ind = tree.query(X[:1], k=10)                # doctest: +SKIP
ind = tree.query(X[:1], k=10, return_distance=False)                # doctest: +SKIP
print(ind)  # indices of 3 closest neighbors
#print(dist)  # distances to 3 closest neighbors
# Out:
# [[0 3 1 7 2 6 9 4 8 5]]

# %%
print(X[:2])
# Out:
# [[0.5488135  0.71518937 0.60276338]
#  [0.54488318 0.4236548  0.64589411]]

# %%
X
# Out:
# array([[0.5488135 , 0.71518937, 0.60276338],
#        [0.54488318, 0.4236548 , 0.64589411],
#        [0.43758721, 0.891773  , 0.96366276],
#        [0.38344152, 0.79172504, 0.52889492],
#        [0.56804456, 0.92559664, 0.07103606],
#        [0.0871293 , 0.0202184 , 0.83261985],
#        [0.77815675, 0.87001215, 0.97861834],
#        [0.79915856, 0.46147936, 0.78052918],
#        [0.11827443, 0.63992102, 0.14335329],
#        [0.94466892, 0.52184832, 0.41466194]])

# %%
#Y = [(-127.4007, -420.8772, 6.3978),
#     (288.4544, 351.2529, 12.1621),
#     (537.0884, 74.9511, 14.9616)]

# %%
Y = np.array([[-7.95731751e+01, -2.58082247e+02,  1.05426798e+01],
       [-2.99178313e+02,  4.18072186e+02,  7.20198542e+00],
       [ 4.23077278e+02, -2.49259310e+02,  1.03512153e+00],
       [ 5.13787804e+02,  3.47295713e+02,  5.15564060e-01],
       [ 2.75588273e+02, -4.22876481e+02,  2.83427871e+00],
       [ 1.65410552e+02,  4.15832931e+02,  2.94686058e+00],
       [ 4.04131953e+01,  2.42828388e+02,  1.10046879e+01],
       [-1.49831448e+02, -3.30619543e+01,  1.00549880e+01],
       [-8.45907193e+01, -2.39310474e+02,  5.51947076e-01],
       [-3.06954635e+01, -2.57514760e+02,  4.74450086e-01],
       [-2.98302471e+02,  2.98257622e+02,  1.64497350e+01],
       [ 2.71554706e+02,  4.68339649e+02,  5.16834335e+00],
       [ 3.99684702e+02,  3.10624779e+02,  3.24621434e+00],
       [-2.39684243e+02, -1.51064409e+02,  3.85613718e+00],
       [-1.48662962e+02,  2.00543253e+02,  5.62655970e+00],
       [ 2.55768699e+02, -1.67628510e+02,  1.83355251e+01],
       [-1.08484142e+02,  2.46506290e+02,  1.13971428e+01],
       [-1.49016418e+02,  2.43446167e+02,  1.72503576e+01],
       [ 3.07140476e+02, -1.89503074e+02,  1.31740618e+01],
       [ 5.10195739e+02,  3.50274934e+02,  1.83240878e+01],
       [ 3.28830335e+02,  3.19264777e+02,  4.26278371e-01],
       [-2.32967354e+02,  2.26067880e+02,  1.35586581e+01],
       [ 3.32461560e+00, -5.85826240e+01,  1.29975948e+01],
       [ 2.47665892e+02,  4.48468675e+02,  1.50599907e+01],
       [-5.70028689e+01, -3.53804955e+01,  3.85277296e+00],
       [ 5.40284959e+02,  2.99786288e+02,  1.53506555e+01],
       [ 5.63091823e+02, -2.12635961e+02,  6.17195058e+00],
       [ 2.17802156e+02, -4.17262243e+02,  1.40741564e+01],
       [ 3.54854692e+02,  9.49001436e+01,  1.41236841e+01],
       [ 5.18082678e+02, -1.78722030e+02,  1.68032316e+01],
       [ 2.16116292e+02,  2.60695443e+02,  1.70287591e+01],
       [ 5.75564803e+02,  4.00473096e+02,  8.37261886e+00],
       [-2.31970494e+02,  1.18184533e+02,  1.73678386e+00],
       [-2.29924903e+02,  2.50094583e+02,  1.11720172e+01],
       [ 5.43124541e+02,  8.41836051e+01,  9.02776185e+00],
       [-1.03403790e+02,  2.49607575e+02,  1.07868916e+01],
       [ 4.80201635e+02,  1.75833669e+02,  1.24584735e+01],
       [ 4.01865107e+02,  2.60033966e+02,  1.69020340e+01],
       [-4.96959135e+01, -3.20570140e+02,  3.89015643e+00],
       [-3.28782880e+01, -2.30359143e+02,  5.07949749e-01],
       [ 5.53079002e+02, -3.90786843e+02,  1.49503821e+00],
       [ 4.30292228e+02, -3.30356906e+02,  1.75369608e+01],
       [ 5.89385386e+02,  4.40405394e+02,  1.35397256e+01],
       [ 6.88676851e+01, -1.08490273e+02,  1.26123614e+01],
       [ 3.17596942e+02, -4.40923246e+02,  3.60247578e+00],
       [ 3.40383229e+02,  3.79609878e+02,  8.98467604e+00],
       [-2.49524068e+02, -2.62904476e+02,  1.45355257e+01],
       [ 1.30107211e+02,  1.84247594e+02,  1.22906262e+01],
       [ 5.33394173e+02, -6.19128828e+01,  1.72061560e+01],
       [ 1.71699307e+02,  1.97871537e+01,  1.18640803e+01],
       [ 1.99229131e+02,  3.60317016e+02,  5.67690075e+00],
       [-4.34046094e+01,  2.64512152e+02,  1.07803978e+01],
       [ 3.09826633e+02,  1.45277920e+02,  9.44238476e+00],
       [ 2.55604317e+02,  4.52454128e+02,  1.38237398e+01],
       [ 8.54361883e+01, -3.33315604e+02,  1.44651696e+01],
       [ 3.07760236e+02, -1.46674748e+01,  1.33141391e+01],
       [ 2.04600818e+02, -2.89015032e+02,  9.67128855e+00]])

# %%
import sys
# !{sys.executable} -m pip install -I networkx==2.4
import pkg_resources
pkg_resources.require("networkx==2.4")
import networkx as nx
from shapely.geometry import Polygon, Point, LineString
# Out:
# ...
#   Using cached networkx-2.4-py3-none-any.whl (1.6 MB)
# ...
#   Using cached decorator-4.4.1-py2.py3-none-any.whl (9.2 kB)
# ...

# %%
filename = 'colliders.csv'
data = np.loadtxt(filename, delimiter=',', dtype='Float64', skiprows=2)

from sampling_probabilistic_roadmap import Sampler
sampler = Sampler(data)
polygons = sampler._polygons

# %%
def can_connect(n1, n2):
    l = LineString([n1, n2])
    for p in polygons:
        if p.crosses(l) and p.height >= min(n1[2], n2[2]):
            return False
    return True

# %%
g = nx.Graph()
trees = KDTree(Y)
#inds = trees.query(Y, k=10, return_distance=False) 
#print(inds)  # indices of 3 closest neighbors

# %%
    for n1 in Y:
        # for each node connect try to connect to k nearest nodes
        idxs = tree.query([n1], 10, return_distance=False)[0]
        
        for idx in idxs:
            n2 = Y[idx]
            if all(n2 == n1):
                continue
            if can_connect(n1, n2):
                g.add_edge(n1[:2], n2[:2], weight=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-b9e8af793c70> in <module>
#       8             continue
#       9         if can_connect(n1, n2):
# ---> 10             g.add_edge(n1[:2], n2[:2], weight=1)
#
# c:\users\aeco4\appdata\local\programs\python\python37\lib\site-packages\networkx\classes\graph.py in add_edge(self, u_of_edge, v_of_edge, **attr)
#     880         u, v = u_of_edge, v_of_edge
#     881         # add nodes
# --> 882         if u not in self._node:
#     883             self._adj[u] = self.adjlist_inner_dict_factory()
#     884             self._node[u] = self.node_attr_dict_factory()
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
print(n2)
print(n1)
all(n2==n1)
print(n2[:2])
